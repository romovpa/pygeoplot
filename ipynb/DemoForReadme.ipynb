# %% [markdown]
# # Demo Notebook for README

# %%
line_points = [
    (55.864414, 37.401979),
    (55.575286, 37.635438),
    (55.845875, 37.801606),
    (55.665433, 37.426698),
    (55.685610, 37.830446),
    (55.864414, 37.401979),
]

# %%
import pygeoplot as gp

m = gp.Map()

m.add_line(line_points, color="#FF0000", width=10, opacity=0.6)
m.set_state([55.72, 37.64], zoom=9.5)
m.add_placemark((55.702770, 37.529184), 
                hint='Alma Mater', content='Moscow State University')
m.add_placemark((55.711552, 37.621861), 
                hint='The Center of the pentagram')

m.display(width=600, height=300, resizeable=True)
# Out:
# <div id="map_5262344557" style="width: 600px; height: 300px"></div>
#
# <script type="text/javascript">
#
# draw_functions = {
#
#     "Placemark": function(map, obj) {
#         properties = {
#             hintContent: obj.hint,
#             balloonContent: obj.content
#         };
#         map.geoObjects.add(
#             new ymaps.Placemark(obj.point, properties)
#         );
#     },
#
#     "Line": function(map, obj) {
#         properties = {
#             hintContent: obj.hint,
#             balloonContent: obj.content
#         };
#         options = {
#             strokeColor: obj.color,
#             strokeWidth: obj.width,
#             strokeOpacity: obj.opacity
#         };
#         map.geoObjects.add(
#             new ymaps.Polyline(obj.points, properties, options)
#         );
#     },
#
#     "Heatmap": function(map, obj) {
#         ymaps.modules.require(['Heatmap'], function (Heatmap) {
#             var heatmap = new Heatmap(obj.points);
#             heatmap.setMap(map);
#         });
#     }
#
# }
#
# function show_map(id, map_data) {
#     ymaps.ready(init);
#
#     var yaMap;
#     function init() {
#
#         yaMap = new ymaps.Map(id, map_data.state);
#
#         map_data.objects.forEach(
#             function(obj) {
#                 draw_func = draw_functions[obj.type];
#                 if (draw_func) {
#                     draw_func(yaMap, obj);
#                 } else {
#                     console.error("Bad object type: "+obj.type);
#                 }
#             }
#         );
#
#     }
# }
#
#
#     require.config({
#         paths: {
#             "ymaps": "http://api-maps.yandex.ru/2.1/?lang=en_US",
#             "heatmap": "https://dl.dropboxusercontent.com/u/20300574/Heatmap.min"
#         }
#     });
#
#     require(['ymaps', 'heatmap'], function() {
#         show_map("map_5262344557", {"state": {"center": [55.72, 37.64], "zoom": 9.5}, "objects": [{"opacity": 0.6, "hint": null, "color": "#FF0000", "content": null, "width": 10, "points": [[55.864414, 37.401979], [55.575286, 37.635438], [55.845875, 37.801606], [55.665433, 37.426698], [55.68561, 37.830446], [55.864414, 37.401979]], "type": "Line"}, {"content": "Moscow State University", "hint": "Alma Mater", "type": "Placemark", "point": [55.70277, 37.529184]}, {"content": null, "hint": "The Center of the pentagram", "type": "Placemark", "point": [55.711552, 37.621861]}]});
#
#
#         $(function() {
#             $("#map_5262344557").resizable();
#             $("#map_5262344557").on("resize", function() { myMap.container.fitToViewport(); })
#         });
#
#     });
#
# </script>

# %%
m.add_placemark((55.711552, 37.621861), hint='A Cat', content='<img width=300 height=200 src="http://www.findcatnames.com/wp-content/uploads/2014/09/453768-cats-cute.jpg" />')
m.display()
# Out:
# <div id="map_346990223" style="width: 640px; height: 480px"></div>
#
# <script type="text/javascript">
#
# draw_functions = {
#
#     "Placemark": function(map, obj) {
#         properties = {
#             hintContent: obj.hint,
#             balloonContent: obj.content
#         };
#         map.geoObjects.add(
#             new ymaps.Placemark(obj.point, properties)
#         );
#     },
#
#     "Line": function(map, obj) {
#         properties = {
#             hintContent: obj.hint,
#             balloonContent: obj.content
#         };
#         options = {
#             strokeColor: obj.color,
#             strokeWidth: obj.width,
#             strokeOpacity: obj.opacity
#         };
#         map.geoObjects.add(
#             new ymaps.Polyline(obj.points, properties, options)
#         );
#     },
#
#     "Heatmap": function(map, obj) {
#         ymaps.modules.require(['Heatmap'], function (Heatmap) {
#             var heatmap = new Heatmap(obj.points);
#             heatmap.setMap(map);
#         });
#     }
#
# }
#
# function show_map(id, map_data) {
#     ymaps.ready(init);
#
#     var yaMap;
#     function init() {
#
#         yaMap = new ymaps.Map(id, map_data.state);
#
#         map_data.objects.forEach(
#             function(obj) {
#                 draw_func = draw_functions[obj.type];
#                 if (draw_func) {
#                     draw_func(yaMap, obj);
#                 } else {
#                     console.error("Bad object type: "+obj.type);
#                 }
#             }
#         );
#
#     }
# }
#
#
#     require.config({
#         paths: {
#             "ymaps": "http://api-maps.yandex.ru/2.1/?lang=en_US",
#             "heatmap": "https://dl.dropboxusercontent.com/u/20300574/Heatmap.min"
#         }
#     });
#
#     require(['ymaps', 'heatmap'], function() {
#         show_map("map_346990223", {"state": {"center": [55.72, 37.64], "zoom": 9.5}, "objects": [{"opacity": 0.6, "hint": null, "color": "#FF0000", "content": null, "width": 10, "points": [[55.864414, 37.401979], [55.575286, 37.635438], [55.845875, 37.801606], [55.665433, 37.426698], [55.68561, 37.830446], [55.864414, 37.401979]], "type": "Line"}, {"content": "Moscow State University", "hint": "Alma Mater", "type": "Placemark", "point": [55.70277, 37.529184]}, {"content": null, "hint": "The Center of the pentagram", "type": "Placemark", "point": [55.711552, 37.621861]}, {"content": "<img src=\"http://www.findcatnames.com/wp-content/uploads/2014/09/453768-cats-cute.jpg\" />", "hint": "Place for Cat", "type": "Placemark", "point": [55.711552, 37.621861]}, {"content": "<img width=300 height=300 src=\"http://www.findcatnames.com/wp-content/uploads/2014/09/453768-cats-cute.jpg\" />", "hint": "Place for Cat", "type": "Placemark", "point": [55.711552, 37.621861]}, {"content": "<img width=300 height=200 src=\"http://www.findcatnames.com/wp-content/uploads/2014/09/453768-cats-cute.jpg\" />", "hint": "Place for Cat", "type": "Placemark", "point": [55.711552, 37.621861]}]});
#
#
#     });
#
# </script>
